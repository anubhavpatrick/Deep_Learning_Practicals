# %% [markdown]
# To visualize tensorflow model, we need to write log files that tensor board can read for visualizations.

# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

print(X)
print(X.shape)

RUN_NAME ='run 2 with 100 input nodes'#Just change this string everytime you twesk the network

# Define the model
model = Sequential()
model.add(Dense(100, input_dim=9, activation='relu', name='layer_1'))#nane of each layer is augmented to make visualizations more clear
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir="log/{}".format(RUN_NAME),
    write_graph= True, #by default keras will only log details of training process but it will not log details of the model
    histogram_freq=5 #information about how each layer of our neural network is working. Here 5 means that for every 5 passes keras will write statistics              
)




# Load the separate test data set
test_data_df = pd.read_csv("sales_data_testing_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values
print(X_test.shape)
# Train the model


model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    validation_data=(X_test,Y_test),
    callbacks=[logger]#an array of functions that we want keras to call after each pass during training phase
)

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# Using TensorFlow backend.
# [[0.5        1.         0.         ... 0.         0.         1.        ]
#  [0.83333333 0.         0.         ... 1.         0.         0.5       ]
#  [0.33333333 0.         0.         ... 1.         0.         0.5       ]
#  ...
#  [0.83333333 0.         1.         ... 0.         0.         1.        ]
#  [0.5        1.         1.         ... 0.         1.         0.        ]
#  [0.33333333 1.         0.         ... 0.         1.         0.5       ]]
# (1000, 9)
# (400, 9)
# Train on 1000 samples, validate on 400 samples
# Epoch 1/50
#  - 1s - loss: 0.0254 - val_loss: 0.0054
# Epoch 2/50
#  - 0s - loss: 0.0026 - val_loss: 0.0011
# Epoch 3/50
#  - 0s - loss: 6.8297e-04 - val_loss: 4.6244e-04
# Epoch 4/50
#  - 0s - loss: 3.2480e-04 - val_loss: 2.8570e-04
# Epoch 5/50
#  - 0s - loss: 1.9856e-04 - val_loss: 2.1083e-04
# Epoch 6/50
#  - 0s - loss: 1.3775e-04 - val_loss: 1.9558e-04
# Epoch 7/50
#  - 0s - loss: 1.0303e-04 - val_loss: 2.0681e-04
# Epoch 8/50
#  - 0s - loss: 1.0771e-04 - val_loss: 1.6621e-04
# Epoch 9/50
#  - 0s - loss: 7.6004e-05 - val_loss: 1.4932e-04
# Epoch 10/50
#  - 0s - loss: 6.0363e-05 - val_loss: 1.4631e-04
# Epoch 11/50
#  - 0s - loss: 7.3701e-05 - val_loss: 1.1355e-04
# Epoch 12/50
#  - 0s - loss: 4.9128e-05 - val_loss: 1.1363e-04
# Epoch 13/50
#  - 0s - loss: 4.2433e-05 - val_loss: 1.0947e-04
# Epoch 14/50
#  - 0s - loss: 6.1165e-05 - val_loss: 2.7751e-04
# Epoch 15/50
#  - 0s - loss: 6.1344e-05 - val_loss: 1.0657e-04
# Epoch 16/50
#  - 0s - loss: 3.7552e-05 - val_loss: 9.9943e-05
# Epoch 17/50
#  - 0s - loss: 3.1987e-05 - val_loss: 1.0057e-04
# Epoch 18/50
#  - 0s - loss: 3.4513e-05 - val_loss: 9.7046e-05
# Epoch 19/50
#  - 0s - loss: 5.0813e-05 - val_loss: 1.0567e-04
# Epoch 20/50
#  - 0s - loss: 4.0080e-05 - val_loss: 9.9572e-05
# Epoch 21/50
#  - 0s - loss: 2.7398e-05 - val_loss: 9.3207e-05
# Epoch 22/50
#  - 0s - loss: 3.4231e-05 - val_loss: 1.0886e-04
# Epoch 23/50
#  - 0s - loss: 2.6363e-05 - val_loss: 8.9054e-05
# Epoch 24/50
#  - 0s - loss: 2.4054e-05 - val_loss: 8.4839e-05
# Epoch 25/50
#  - 0s - loss: 2.5298e-05 - val_loss: 1.6605e-04
# Epoch 26/50
#  - 0s - loss: 4.4353e-05 - val_loss: 1.0825e-04
# Epoch 27/50
#  - 0s - loss: 2.5592e-05 - val_loss: 8.8031e-05
# Epoch 28/50
#  - 0s - loss: 2.3916e-05 - val_loss: 9.1605e-05
# Epoch 29/50
#  - 0s - loss: 3.6912e-05 - val_loss: 9.6199e-05
# Epoch 30/50
#  - 0s - loss: 2.1528e-05 - val_loss: 8.0212e-05
# Epoch 31/50
#  - 0s - loss: 2.2305e-05 - val_loss: 8.6992e-05
# Epoch 32/50
#  - 0s - loss: 2.7295e-05 - val_loss: 7.8387e-05
# Epoch 33/50
#  - 0s - loss: 2.0200e-05 - val_loss: 9.0419e-05
# Epoch 34/50
#  - 0s - loss: 1.7982e-05 - val_loss: 8.9551e-05
# Epoch 35/50
#  - 0s - loss: 3.1162e-05 - val_loss: 8.8043e-05
# Epoch 36/50
#  - 0s - loss: 1.7561e-05 - val_loss: 8.4414e-05
# Epoch 37/50
#  - 0s - loss: 2.1250e-05 - val_loss: 1.1175e-04
# Epoch 38/50
#  - 0s - loss: 1.7094e-05 - val_loss: 8.5395e-05
# Epoch 39/50
#  - 0s - loss: 2.0234e-05 - val_loss: 9.3046e-05
# Epoch 40/50
#  - 0s - loss: 2.5375e-05 - val_loss: 8.5569e-05
# Epoch 41/50
#  - 0s - loss: 2.5134e-05 - val_loss: 8.1162e-05
# Epoch 42/50
#  - 0s - loss: 2.8556e-05 - val_loss: 9.3912e-05
# Epoch 43/50
#  - 0s - loss: 1.8524e-05 - val_loss: 8.8254e-05
# Epoch 44/50
#  - 0s - loss: 2.4604e-05 - val_loss: 1.1200e-04
# Epoch 45/50
#  - 0s - loss: 2.6583e-05 - val_loss: 9.7081e-05
# Epoch 46/50
#  - 0s - loss: 1.8114e-05 - val_loss: 9.1290e-05
# Epoch 47/50
#  - 0s - loss: 2.1103e-05 - val_loss: 1.0671e-04
# Epoch 48/50
#  - 0s - loss: 2.7858e-05 - val_loss: 1.0082e-04
# Epoch 49/50
#  - 0s - loss: 3.2365e-05 - val_loss: 1.4808e-04
# Epoch 50/50
#  - 0s - loss: 5.0430e-05 - val_loss: 1.3839e-04
# The mean squared error (MSE) for the test data set is: 0.00013839045015629381

# %% [markdown]
# - if any error occur we may be required to restart kernel
# - to start tensorboard use tensorboard --logdir=directory
# - In the scalar tab click on LOSS. Y axis represents Loss, X axis #of passes
# - copy paste port num to http://localhost:6006
